# %%
import os
import pandas as pd
from farcaster import Warpcast
from dotenv import load_dotenv # can be installed with `pip install python-dotenv`

load_dotenv()
# Out:
# True

# %%
import requests as r
NEYNAR_API_KEY = os.getenv('NEYNAR_API_KEY')

# %%
def query_neynar_api(endpoint, params=None):
    sucessful_calls = 0
    base_url = "https://hub-api.neynar.com/v1/"
    headers = {
        "Content-Type": "application/json",
        "api_key": NEYNAR_API_KEY,
    }
    url = f"{base_url}{endpoint}"
    if params is None:
        params = {}
    
    params['pageSize'] = 1000
    all_messages = []
    
    max_retries = 3
    retry_delay = 1  

    while True:
        for attempt in range(max_retries):
            try:
                response = requests.get(url, headers=headers, params=params)
                response.raise_for_status()
                data = response.json()
                
                if 'messages' in data:
                    sucessful_calls += 1
                    print(f"Successful call number: {sucessful_calls}")
                    print(f"New messages retrieved: {len(data['messages'])}...")
                    all_messages.extend(data['messages'])
                    print(f"Retrieved {len(all_messages)} messages total...")
                if 'nextPageToken' in data and data['nextPageToken']:
                    params['pageToken'] = data['nextPageToken']
                    break  # Successful, move to next page
                else:
                    return all_messages  # No more pages, return all messages
                
            except RequestException as e:
                if attempt == max_retries - 1:
                    print(f"Failed after {max_retries} attempts. Error: {e}")
                    return all_messages  # Return whatever messages we've collected so far
                else:
                    print(f"Attempt {attempt + 1} failed. Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                    retry_delay *= 2  # Exponential backoff
    
    return all_messages

# %%
users_endpoint = 'userDataByFid'
users_params = {
    'fid': 5,
    'USER_DATA_TYPE':'USER_DATA_TYPE_DISPLAY'
}

# %%
my_user_data = query_neynar_api(endpoint=users_endpoint, params=users_params)

# %%
my_user_data
# Out:
# [{'data': {'type': 'MESSAGE_TYPE_USER_DATA_ADD',
#    'fid': 5,
#    'timestamp': 73414838,
#    'network': 'FARCASTER_NETWORK_MAINNET',
#    'userDataBody': {'type': 'USER_DATA_TYPE_PFP',
#     'value': 'https://i.seadn.io/gcs/files/1d12ec3563a9b6abac76d9636c5ed9ac.jpg?w=500&auto=format'}},
#   'hash': '0x8fa30f7cc6d9973fb5f588c6af0af32ca73880eb',
#   'hashScheme': 'HASH_SCHEME_BLAKE3',
#   'signature': 'UXBgkvEkHSprfK13qYQ6/SYlQOIuD7LYHq/b/hgj0tqZYLwgh3GhG2qkIE8wFlN9so5Cjl9AK2f0HafHjPAaDQ==',
#   'signatureScheme': 'SIGNATURE_SCHEME_ED25519',
#   'signer': '0x652fac6bd16500b46a6c8102edcd665c5d5aeee17ac52f219a017e3d35449831'},
#  {'data': {'type': 'MESSAGE_TYPE_USER_DATA_ADD',
#    'fid': 5,
#    'timestamp': 79111825,
#    'network': 'FARCASTER_NETWORK_MAINNET',
#    'userDataBody': {'type': 'USER_DATA_TYPE_BIO',
#     'value': 'https://mirceap.com'}},
#   'hash': '0x96b4686c46cffb45cd801d9e1bf382478b80038f',
#   'hashScheme': 'HASH_SCHEME_BLAKE3',
#   'signature': '4o9Uf3aNvir9Rjg8UeuXP/N+pMYHKWPNvlErtnrxuTWn9Wq4COhhzjCBJ0azArtDuC7I8JygAlZ4K6xNp8PNDQ==',
#   'signatureScheme': 'SIGNATURE_SCHEME_ED25519',
#   'signer': '0x652fac6bd16500b46a6c8102edcd665c5d5aeee17ac52f219a017e3d35449831'},
#  {'data': {'type': 'MESSAGE_TYPE_USER_DATA_ADD',
#    'fid': 5,
#    'timestamp': 80977158,
#    'network': 'FARCASTER_NETWORK_MAINNET',
#    'userDataBody': {'type': 'USER_DATA_TYPE_USERNAME', 'value': 'mircea.eth'}},
#   'hash': '0xe95364e96886498c6b9ff93fe58f1960c96b5f74',
#   'hashScheme': 'HASH_SCHEME_BLAKE3',
#   'signature': 'Pu+TLsLAlV3U/lQSjZt1G4IisGcgqdgj0lN3PvCKWmBh0LEPEWZ/Qwy36BEXPyRZTDmQ1qPKyIY7+z3CeDiwCw==',
#   'signatureScheme': 'SIGNATURE_SCHEME_ED25519',
#   'signer': '0x652fac6bd16500b46a6c8102edcd665c5d5aeee17ac52f219a017e3d35449831'},
#  {'data': {'type': 'MESSAGE_TYPE_USER_DATA_ADD',
#    'fid': 5,
#    'timestamp': 80977174,
#    'network': 'FARCASTER_NETWORK_MAINNET',
#    'userDataBody': {'type': 'USER_DATA_TYPE_DISPLAY',
#     'value': 'Mircea Pasoi'}},
#   'hash': '0x47b4468899f0201d352cd2680522f60e26eadad4',
#   'hashScheme': 'HASH_SCHEME_BLAKE3',
#   'signature': 'jmAzCtoqjs6ln0MWMPlPp+MdTsiKbanI2OieiAiybqQjIZW2W/fJAYsBEz+vTBz44VusHLcKLK01vy0dNL7XAQ==',
#   'signatureScheme': 'SIGNATURE_SCHEME_ED25519',
#   'signer': '0x652fac6bd16500b46a6c8102edcd665c5d5aeee17ac52f219a017e3d35449831'}]

# %%
follows_endpoint = "linksByFid"
follows_params = {
    "link_type": 'follow',
    "fid": 1689,
}

# %%
follows = query_neynar_api(endpoint=follows_endpoint, params=follows_params)

# %%
len(follows)
# Out:
# 1081

# %%
followers_endpoint = "linksByTargetFid"
followers_params = {
    "link_type": 'follow',
    "target_fid": 1689,
}

# %%
followers = query_neynar_api(endpoint=following_endpoint, params=following_params)
# Out:
# Successful call number: 1
# New messages retrieved: 1000...
# Retrieved 1000 messages total...
# Successful call number: 2
# New messages retrieved: 1000...
# Retrieved 2000 messages total...
# Successful call number: 3
# New messages retrieved: 1000...
# Retrieved 3000 messages total...
# Successful call number: 4
# New messages retrieved: 1000...
# Retrieved 4000 messages total...
# Successful call number: 5
# New messages retrieved: 1000...
# Retrieved 5000 messages total...
# Successful call number: 6
# New messages retrieved: 1000...
# Retrieved 6000 messages total...
# Successful call number: 7
# New messages retrieved: 1000...
# Retrieved 7000 messages total...
# Successful call number: 8
# New messages retrieved: 1000...
# Retrieved 8000 messages total...
# Successful call number: 9
# New messages retrieved: 1000...
# Retrieved 9000 messages total...
# Successful call number: 10
# New messages retrieved: 1000...
# Retrieved 10000 messages total...
# Successful call number: 11
# New messages retrieved: 1000...
# Retrieved 11000 messages total...
# Successful call number: 12
# New messages retrieved: 1000...
# Retrieved 12000 messages total...
# Successful call number: 13
# New messages retrieved: 1000...
# Retrieved 13000 messages total...
# Successful call number: 14
# New messages retrieved: 1000...
# Retrieved 14000 messages total...
# Successful call number: 15
# New messages retrieved: 1000...
# Retrieved 15000 messages total...
# Successful call number: 16
# New messages retrieved: 1000...
# Retrieved 16000 messages total...
# Successful call number: 17
# New messages retrieved: 1000...
# Retrieved 17000 messages total...
# Successful call number: 18
# New messages retrieved: 1000...
# Retrieved 18000 messages total...
# Successful call number: 19
# New messages retrieved: 1000...
# Retrieved 19000 messages total...
# Successful call number: 20
# New messages retrieved: 1000...
# Retrieved 20000 messages total...
# Successful call number: 21
# New messages retrieved: 1000...
# Retrieved 21000 messages total...
# Successful call number: 22
# New messages retrieved: 1000...
# Retrieved 22000 messages total...
# Successful call number: 23
# New messages retrieved: 1000...
# Retrieved 23000 messages total...
# Successful call number: 24
# New messages retrieved: 1000...
# Retrieved 24000 messages total...
# Successful call number: 25
# New messages retrieved: 1000...
# Retrieved 25000 messages total...
# Successful call number: 26
# New messages retrieved: 1000...
# Retrieved 26000 messages total...
# Successful call number: 27
# New messages retrieved: 1000...
# Retrieved 27000 messages total...
# Successful call number: 28
# New messages retrieved: 1000...
# Retrieved 28000 messages total...
# Successful call number: 29
# New messages retrieved: 1000...
# Retrieved 29000 messages total...
# Successful call number: 30
# New messages retrieved: 1000...
# Retrieved 30000 messages total...
# Successful call number: 31
# New messages retrieved: 1000...
# Retrieved 31000 messages total...
# Successful call number: 32
# New messages retrieved: 1000...
# Retrieved 32000 messages total...
# Successful call number: 33
# New messages retrieved: 1000...
# Retrieved 33000 messages total...
# Successful call number: 34
# New messages retrieved: 1000...
# Retrieved 34000 messages total...
# Successful call number: 35
# New messages retrieved: 1000...
# Retrieved 35000 messages total...
# Successful call number: 36
# New messages retrieved: 1000...
# Retrieved 36000 messages total...
# Successful call number: 37
# New messages retrieved: 1000...
# Retrieved 37000 messages total...
# Successful call number: 38
# New messages retrieved: 1000...
# Retrieved 38000 messages total...
# Successful call number: 39
# New messages retrieved: 1000...
# Retrieved 39000 messages total...
# Successful call number: 40
# New messages retrieved: 1000...
# Retrieved 40000 messages total...
# Successful call number: 41
# New messages retrieved: 1000...
# Retrieved 41000 messages total...
# Successful call number: 42
# New messages retrieved: 1000...
# Retrieved 42000 messages total...
# Successful call number: 43
# New messages retrieved: 1000...
# Retrieved 43000 messages total...
# Successful call number: 44
# New messages retrieved: 1000...
# Retrieved 44000 messages total...
# Successful call number: 45
# New messages retrieved: 1000...
# Retrieved 45000 messages total...
# Successful call number: 46
# New messages retrieved: 1000...
# Retrieved 46000 messages total...
# Successful call number: 47
# New messages retrieved: 1000...
# Retrieved 47000 messages total...
# Successful call number: 48
# New messages retrieved: 1000...
# Retrieved 48000 messages total...
# Successful call number: 49
# New messages retrieved: 1000...
# Retrieved 49000 messages total...
# Successful call number: 50
# New messages retrieved: 1000...
# Retrieved 50000 messages total...
# Successful call number: 51
# New messages retrieved: 1000...
# Retrieved 51000 messages total...
# Successful call number: 52
# New messages retrieved: 1000...
# Retrieved 52000 messages total...
# Successful call number: 53
# New messages retrieved: 1000...
# Retrieved 53000 messages total...
# Successful call number: 54
# New messages retrieved: 1000...
# Retrieved 54000 messages total...
# Successful call number: 55
# New messages retrieved: 1000...
# Retrieved 55000 messages total...
# Successful call number: 56
# New messages retrieved: 1000...
# Retrieved 56000 messages total...
# Successful call number: 57
# New messages retrieved: 1000...
# Retrieved 57000 messages total...
# Successful call number: 58
# New messages retrieved: 1000...
# Retrieved 58000 messages total...
# Successful call number: 59
# New messages retrieved: 1000...
# Retrieved 59000 messages total...
# Successful call number: 60
# New messages retrieved: 1000...
# Retrieved 60000 messages total...
# Successful call number: 61
# New messages retrieved: 1000...
# Retrieved 61000 messages total...
# Successful call number: 62
# New messages retrieved: 1000...
# Retrieved 62000 messages total...
# Successful call number: 63
# New messages retrieved: 1000...
# Retrieved 63000 messages total...
# Successful call number: 64
# New messages retrieved: 1000...
# Retrieved 64000 messages total...
# Successful call number: 65
# New messages retrieved: 1000...
# Retrieved 65000 messages total...
# Successful call number: 66
# New messages retrieved: 1000...
# Retrieved 66000 messages total...
# Successful call number: 67
# New messages retrieved: 1000...
# Retrieved 67000 messages total...
# Successful call number: 68
# New messages retrieved: 1000...
# Retrieved 68000 messages total...
# Successful call number: 69
# New messages retrieved: 1000...
# Retrieved 69000 messages total...
# Successful call number: 70
# New messages retrieved: 1000...
# Retrieved 70000 messages total...
# Successful call number: 71
# New messages retrieved: 1000...
# Retrieved 71000 messages total...
# Successful call number: 72
# New messages retrieved: 1000...
# Retrieved 72000 messages total...
# Successful call number: 73
# New messages retrieved: 1000...
# Retrieved 73000 messages total...
# Successful call number: 74
# New messages retrieved: 1000...
# Retrieved 74000 messages total...
# Successful call number: 75
# New messages retrieved: 1000...
# Retrieved 75000 messages total...
# Successful call number: 76
# New messages retrieved: 1000...
# Retrieved 76000 messages total...
# Successful call number: 77
# New messages retrieved: 1000...
# Retrieved 77000 messages total...
# Successful call number: 78
# New messages retrieved: 1000...
# Retrieved 78000 messages total...
# Successful call number: 79
# New messages retrieved: 1000...
# Retrieved 79000 messages total...
# Successful call number: 80
# New messages retrieved: 1000...
# Retrieved 80000 messages total...
# Successful call number: 81
# New messages retrieved: 1000...
# Retrieved 81000 messages total...
# Successful call number: 82
# New messages retrieved: 1000...
# Retrieved 82000 messages total...
# Successful call number: 83
# New messages retrieved: 1000...
# Retrieved 83000 messages total...
# Successful call number: 84
# New messages retrieved: 1000...
# Retrieved 84000 messages total...
# Successful call number: 85
# New messages retrieved: 1000...
# Retrieved 85000 messages total...
# Successful call number: 86
# New messages retrieved: 1000...
# Retrieved 86000 messages total...
# Successful call number: 87
# New messages retrieved: 1000...
# Retrieved 87000 messages total...
# Successful call number: 88
# New messages retrieved: 1000...
# Retrieved 88000 messages total...
# Successful call number: 89
# New messages retrieved: 1000...
# Retrieved 89000 messages total...
# Successful call number: 90
# New messages retrieved: 1000...
# Retrieved 90000 messages total...
# Successful call number: 91
# New messages retrieved: 1000...
# Retrieved 91000 messages total...
# Successful call number: 92
# New messages retrieved: 1000...
# Retrieved 92000 messages total...
# Successful call number: 93
# New messages retrieved: 1000...
# Retrieved 93000 messages total...
# Successful call number: 94
# New messages retrieved: 1000...
# Retrieved 94000 messages total...
# Successful call number: 95
# New messages retrieved: 1000...
# Retrieved 95000 messages total...
# Successful call number: 96
# New messages retrieved: 1000...
# Retrieved 96000 messages total...
# Successful call number: 97
# New messages retrieved: 1000...
# Retrieved 97000 messages total...
# Successful call number: 98
# New messages retrieved: 1000...
# Retrieved 98000 messages total...
# Successful call number: 99
# New messages retrieved: 1000...
# Retrieved 99000 messages total...
# Successful call number: 100
# New messages retrieved: 1000...
# Retrieved 100000 messages total...
# Successful call number: 101
# New messages retrieved: 1000...
# Retrieved 101000 messages total...
# Successful call number: 102
# New messages retrieved: 1000...
# Retrieved 102000 messages total...
# Successful call number: 103
# New messages retrieved: 1000...
# Retrieved 103000 messages total...
# Successful call number: 104
# New messages retrieved: 1000...
# Retrieved 104000 messages total...
# Successful call number: 105
# New messages retrieved: 1000...
# Retrieved 105000 messages total...
# Successful call number: 106
# New messages retrieved: 1000...
# Retrieved 106000 messages total...
# Successful call number: 107
# New messages retrieved: 1000...
# Retrieved 107000 messages total...
# Successful call number: 108
# New messages retrieved: 1000...
# Retrieved 108000 messages total...
# Successful call number: 109
# New messages retrieved: 1000...
# Retrieved 109000 messages total...
# Successful call number: 110
# New messages retrieved: 1000...
# Retrieved 110000 messages total...
# Successful call number: 111
# New messages retrieved: 1000...
# Retrieved 111000 messages total...
# Successful call number: 112
# New messages retrieved: 1000...
# Retrieved 112000 messages total...
# Successful call number: 113
# New messages retrieved: 1000...
# Retrieved 113000 messages total...
# Successful call number: 114
# New messages retrieved: 1000...
# Retrieved 114000 messages total...
# Successful call number: 115
# New messages retrieved: 1000...
# Retrieved 115000 messages total...
# Successful call number: 116
# New messages retrieved: 1000...
# Retrieved 116000 messages total...
# Successful call number: 117
# New messages retrieved: 1000...
# Retrieved 117000 messages total...
# Successful call number: 118
# New messages retrieved: 1000...
# Retrieved 118000 messages total...
# Successful call number: 119
# New messages retrieved: 1000...
# Retrieved 119000 messages total...
# Successful call number: 120
# New messages retrieved: 1000...
# Retrieved 120000 messages total...
# Successful call number: 121
# New messages retrieved: 1000...
# Retrieved 121000 messages total...
# Successful call number: 122
# New messages retrieved: 1000...
# Retrieved 122000 messages total...
# Successful call number: 123
# New messages retrieved: 1000...
# Retrieved 123000 messages total...
# Successful call number: 124
# New messages retrieved: 1000...
# Retrieved 124000 messages total...
# Successful call number: 125
# New messages retrieved: 1000...
# Retrieved 125000 messages total...
# Successful call number: 126
# New messages retrieved: 1000...
# Retrieved 126000 messages total...
# Successful call number: 127
# New messages retrieved: 1000...
# Retrieved 127000 messages total...
# Successful call number: 128
# New messages retrieved: 1000...
# Retrieved 128000 messages total...
# Successful call number: 129
# New messages retrieved: 1000...
# Retrieved 129000 messages total...
# Successful call number: 130
# New messages retrieved: 1000...
# Retrieved 130000 messages total...
# Successful call number: 131
# New messages retrieved: 1000...
# Retrieved 131000 messages total...
# Successful call number: 132
# New messages retrieved: 1000...
# Retrieved 132000 messages total...
# Successful call number: 133
# New messages retrieved: 1000...
# Retrieved 133000 messages total...
# Successful call number: 134
# New messages retrieved: 1000...
# Retrieved 134000 messages total...
# Successful call number: 135
# New messages retrieved: 1000...
# Retrieved 135000 messages total...
# Successful call number: 136
# New messages retrieved: 1000...
# Retrieved 136000 messages total...
# Successful call number: 137
# New messages retrieved: 1000...
# Retrieved 137000 messages total...
# Successful call number: 138
# New messages retrieved: 1000...
# Retrieved 138000 messages total...
# Successful call number: 139
# New messages retrieved: 1000...
# Retrieved 139000 messages total...
# Successful call number: 140
# New messages retrieved: 1000...
# Retrieved 140000 messages total...
# Successful call number: 141
# New messages retrieved: 1000...
# Retrieved 141000 messages total...
# Successful call number: 142
# New messages retrieved: 1000...
# Retrieved 142000 messages total...
# Successful call number: 143
# New messages retrieved: 1000...
# Retrieved 143000 messages total...
# Successful call number: 144
# New messages retrieved: 1000...
# Retrieved 144000 messages total...
# Successful call number: 145
# New messages retrieved: 1000...
# Retrieved 145000 messages total...
# Successful call number: 146
# New messages retrieved: 1000...
# Retrieved 146000 messages total...
# Successful call number: 147
# New messages retrieved: 1000...
# Retrieved 147000 messages total...
# Successful call number: 148
# New messages retrieved: 1000...
# Retrieved 148000 messages total...
# Successful call number: 149
# New messages retrieved: 1000...
# Retrieved 149000 messages total...
# Successful call number: 150
# New messages retrieved: 1000...
# Retrieved 150000 messages total...
# Successful call number: 151
# New messages retrieved: 1000...
# Retrieved 151000 messages total...
# Successful call number: 152
# New messages retrieved: 1000...
# Retrieved 152000 messages total...
# Successful call number: 153
# New messages retrieved: 1000...
# Retrieved 153000 messages total...
# Successful call number: 154
# New messages retrieved: 1000...
# Retrieved 154000 messages total...
# Successful call number: 155
# New messages retrieved: 1000...
# Retrieved 155000 messages total...
# Successful call number: 156
# New messages retrieved: 1000...
# Retrieved 156000 messages total...
# Successful call number: 157
# New messages retrieved: 1000...
# Retrieved 157000 messages total...
# Successful call number: 158
# New messages retrieved: 1000...
# Retrieved 158000 messages total...
# Successful call number: 159
# New messages retrieved: 1000...
# Retrieved 159000 messages total...
# Successful call number: 160
# New messages retrieved: 639...
# Retrieved 159639 messages total...

# %%
casts_endpoint = "castsByFid"
casts_params = {
    'fid': 1689
}

# %%
casts = query_neynar_api(endpoint=casts_endpoint, params=casts_params)
# Out:
# Successful call number: 1
# New messages retrieved: 1000...
# Retrieved 1000 messages total...
# Successful call number: 2
# New messages retrieved: 1000...
# Retrieved 2000 messages total...
# Successful call number: 3
# New messages retrieved: 1000...
# Retrieved 3000 messages total...
# Successful call number: 4
# New messages retrieved: 1000...
# Retrieved 4000 messages total...
# Successful call number: 5
# New messages retrieved: 1000...
# Retrieved 5000 messages total...
# Successful call number: 6
# New messages retrieved: 872...
# Retrieved 5872 messages total...

# %%
casts[10]
# Out:
# {'data': {'type': 'MESSAGE_TYPE_CAST_ADD',
#   'fid': 1689,
#   'timestamp': 53334588,
#   'network': 'FARCASTER_NETWORK_MAINNET',
#   'castAddBody': {'embedsDeprecated': [],
#    'mentions': [],
#    'parentCastId': {'fid': 1325,
#     'hash': '0x6cca915a78b4508ab801040e90a34a248455d6a3'},
#    'text': 'True. Do you have any solutions or preventative measures in mind?',
#    'mentionsPositions': [],
#    'embeds': [],
#    'type': 'CAST'}},
#  'hash': '0x7e4b719beac4ac5998a6cbba819088acc61b7f92',
#  'hashScheme': 'HASH_SCHEME_BLAKE3',
#  'signature': 'EJQ44Y+DFIqhubdkH7ZvuGKW+5zspaWVPxYm31TNd99AhUJBgPu/i7KQ/2xN13+f3tD7qnGKoglPOkWrchV5Bw==',
#  'signatureScheme': 'SIGNATURE_SCHEME_ED25519',
#  'signer': '0xa5f666cac97ae9f09f78cfaaa624ea2a1f03f042aa87c955d0113275e54e9cfe'}

# %%
mentions_endpoint = 'castsByMention'
mentions_params = {
    'fid': 1689
}

# %%
mentions = query_neynar_api(endpoint=mentions_endpoint, params=mentions_params)
# Out:
# Successful call number: 1
# New messages retrieved: 1000...
# Retrieved 1000 messages total...
# Successful call number: 2
# New messages retrieved: 202...
# Retrieved 1202 messages total...

# %%
mentions[100]
# Out:
# {'data': {'type': 'MESSAGE_TYPE_CAST_ADD',
#   'fid': 4923,
#   'timestamp': 90678747,
#   'network': 'FARCASTER_NETWORK_MAINNET',
#   'castAddBody': {'embedsDeprecated': [],
#    'mentions': [10259, 1689, 5395, 191, 20270],
#    'parentUrl': 'chain://eip155:1/erc721:0x7dd4e31f1530ac682c8ea4d8016e95773e08d8b0',
#    'text': "expanding on my Figma client idea \n\nas far as I can tell, it is possible to read / write comments through a Plugin using REST APIs -- so a Farcaster client could potentially provide contextual communication within comments\n\nplease please let's do this\n\ncc     ",
#    'mentionsPositions': [256, 257, 258, 259, 260],
#    'embeds': [{'url': 'https://i.imgur.com/l1srrKg.png'}],
#    'type': 'CAST'}},
#  'hash': '0x66105ac76364650b89b64a47395d09231dd8227b',
#  'hashScheme': 'HASH_SCHEME_BLAKE3',
#  'signature': 'XEI+XGAajI3792wg8TVxRF30vTRRj2TUXKBHJrpgZQpvZ8EfMWPtKe6cHPs1FnJ7HqEIJuksPaqmocqNekT0AQ==',
#  'signatureScheme': 'SIGNATURE_SCHEME_ED25519',
#  'signer': '0x39c5edea2aa1b3073000c340f8324d7249dd139e105e8ebad7e70f0095043f4e'}
